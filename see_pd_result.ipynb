# %%
import pandas as pd
#显示所有列(参数设置为None代表显示所有行，也可以自行设置数字)
pd.set_option('display.max_columns',None)
#显示所有行
pd.set_option('display.max_rows',None)

# %%
file_name = "EQ Power 3.xlsx"
df = pd.read_excel(file_name, sheet_name="工作表4")

# %%
df
# Out:
#               日期\n(日均KW)          HCDA         LCDA          8CH   14CH&熱回收系統  \
# 0    2017-04-01 00:00:00   7949.270879  5286.205482   583.551569  3680.268958
# 1    2017-04-02 00:00:00   8118.268644  5350.732155   585.948667  3669.635014
# 2    2017-04-03 00:00:00   8134.606583  5206.324107    611.09525  4029.635242
# 3    2017-04-04 00:00:00   8065.068332  5231.816842   627.764421   4238.94634
# 4    2017-04-05 00:00:00   7905.884257  5268.202005   986.958764  4396.344979
# 5    2017-04-06 00:00:00   7940.935728  5226.830436  1318.707408  4508.488333
# 6    2017-04-07 00:00:00   8136.884931  5274.087004  1482.881271  4672.785639
# 7    2017-04-08 00:00:00   8248.764299  5292.921209   1515.00778  4931.828395
# 8    2017-04-09 00:00:00   8046.304789  5299.256818  1558.803451  4974.817521
# 9    2017-04-10 00:00:00          8040  5145.139962         1550         4977
# 10   2017-04-11 00:00:00   7984.139628  5231.314772  1299.734047  4906.026175
# ...
